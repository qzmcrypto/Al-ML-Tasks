# %% [markdown]
# # Task 03: Addition of Two Numbers
#
# **Student Name:** Qalb E Zahra Mashhadi
# **Program:** NAVTTC — Artificial Intelligence (ML & DL)
#
# ---
#
# ## 1. Objective
#
# To demonstrate basic arithmetic operations and string formatting in Python by calculating the sum of two variables.
#
# ---
#
# ## 2. Learning Outcomes
#
# - **Variables:** Declaring and initializing numeric values.
# - **Arithmetic:** Using the `+` operator for addition.
# - **Formatting:** Using the `.format()` method for structured output.
#
# ---
#
# ## 3. Conclusion
#
# The task confirms that Python successfully handles floating-point arithmetic and produces the expected output using dynamic string formatting.

# %%
num1 = 1.5
num2 = 6.3

sum = num1 + num2

print('The sum of {0} and {1} is {2}'.format(num1, num2, sum))
# Out:
# The sum of 1.5 and 6.3 is 7.8
