# %% [markdown]
# # Task 05: Square Root Calculation
#
# **Student Name:** Qalb E Zahra Mashhadi
# **Program:** NAVTTC — Artificial Intelligence (ML & DL)
#
# ---
#
# ## 1. Objective
#
# To demonstrate how to calculate the square root of a number in Python using the exponentiation operator.
#
# ---
#
# ## 2. Learning Outcomes
#
# - **Exponent Operator:** Using `**` to calculate powers (specifically `0.5` for square roots).
# - **Variable Assignment:** Storing numeric values and their calculated results.
# - **String Formatting:** Using the `%` operator for precision-based output formatting.
#
# ---
#
# ## 3. Conclusion
#
# The task confirms that Python can efficiently perform root calculations using basic operators and display results with specific decimal precision.

# %%
num = 8

num_sqrt = num ** 0.5

print('The square root of %0.3f is %0.3f'%(num, num_sqrt))
# Out:
# The square root of 8.000 is 2.828
