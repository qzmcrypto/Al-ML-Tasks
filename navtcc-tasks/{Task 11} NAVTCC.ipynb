# %% [markdown]
# # Task 11: Conditional Execution (If Statement)
#
# **Student Name:** Qalb E Zahra Mashhadi
# **Program:** NAVTTC — Artificial Intelligence (ML & DL)
#
# ---
#
# ## 1. Objective
#
# To understand the flow of control in Python using a simple if statement and observe how indentation defines code blocks.
#
# ---
#
# ## 2. Learning Outcomes
#
# - **Conditional Logic:** Evaluating a boolean expression (`i > 15`).
# - **Indentation:** Recognizing that the print statement inside the if block only executes if the condition is True.
# - **Sequential Execution:** Confirming that code outside the indented block executes regardless of the condition.
#
# ---
#
# ## 3. Conclusion
#
# The task confirms that since the condition `10 > 15` is False, the indented block is skipped, and only the subsequent unindented statement is executed. This is a fundamental concept for building decision-making algorithms in AI.

# %%
i = 10
if (i > 15):
    print("10 is less than 15")
print("I am Not in if")
# Out:
# I am Not in if
