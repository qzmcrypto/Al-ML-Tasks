# %% [markdown]
# # **Task 42: Pandas — DataFrames and Read CSV**
#
# **Student Name:** Qalb E Zahra Mashhadi
# **Program:** NAVTTC — Artificial Intelligence (ML & DL)
#
# ---
#
# ## **1. Objective**
#
# The objective of this task is to **set up the Pandas library** in the environment and learn the correct way to import it. We will also learn how to use an **alias** (`pd`) to make the code shorter and easier to read.
#
# ---
#
# ## **2. Learning Outcomes**
#
# * **Installation:** Understanding how to install the library using `pip install pandas`.
#
# * **Importing Pandas:** Activating the library using `import pandas`.
#
# * **Alias (pd):** Learning why `import pandas as pd` is used (to shorten the code).
#
# * **DataFrame Basics:** Converting a simple dictionary into a Pandas DataFrame and printing it in tabular format.
#
# * **Version Check:** Using `pd.__version__` to check which version of Pandas is installed on the computer.
#
# ---
#
# ## **3. Conclusion**
#
# Installing and importing Pandas is the first practical step in **AI programming**. Using the alias `pd` is a **standard practice** followed worldwide. Converting data into a **DataFrame** prepares it for processing, which is essential for building **Machine Learning models**.

# %%
import pandas as pd

# --- 1. Checking Pandas Version ---

print(f"Pandas Version: {pd.__version__}")
print("-" * 30)
# Out:
# Pandas Version: 2.3.3
# ------------------------------

# %%
# --- 2. Creating a simple dataset ---

mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

# %%
# --- 3. Loading data into a DataFrame ---

myvar = pd.DataFrame(mydataset)

# %%
# --- 4. Printing the Result ---

print("Simple Pandas DataFrame:")
print(myvar)
# Out:
# Simple Pandas DataFrame:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2
