# %% [markdown]
# # Task 04: Addition of User Input Numbers
#
# **Student Name:** Qalb E Zahra Mashhadi
# **Program:** NAVTTC — Artificial Intelligence (ML & DL)
#
# ---
#
# ## 1. Objective
#
# To demonstrate how to take user input in Python, perform type conversion from string to float, and display the calculated sum.
#
# ---
#
# ## 2. Learning Outcomes
#
# - **Input Handling:** Using the `input()` function to take data from the user.
# - **Type Casting:** Converting string inputs into `float` to perform mathematical operations.
# - **Arithmetic:** Calculating the sum of dynamic user-provided values.
#
# ---
#
# ## 3. Conclusion
#
# The task confirms that Python successfully handles user inputs and type casting, ensuring that mathematical operations are performed accurately on floating-point numbers.

# %%
num1 = input('Enter first number: ') 
num2 = input('Enter second number: ') 

sum = float(num1) + float(num2)

print('The sum of {0} and {1} is {2}'.format(num1, num2, sum))
# Out:
# Enter first number:  3
# Enter second number:  77
# The sum of 3 and 77 is 80.0
